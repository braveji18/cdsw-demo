# %%
import pandas as pd
import seaborn as sns

# Basic Data Manipulation
# -----------------------
#
# Use the seaborn tips dataset to generate a best fitting linear regression line

tips = sns.load_dataset("tips")
sns.set(font="DejaVu Sans")
sns.jointplot("total_bill", "tip", tips, kind='reg').fig.suptitle("Tips Regression", y=1.01)

# Examine the difference between smokers and non smokers
sns.lmplot("total_bill", "tip", tips, col="smoker").fig.suptitle("Tips Regression - categorized by smoker", y=1.05)

# Explore the dataframe
tips.head()
# Out:
# /opt/conda/envs/python3.6/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/envs/python3.6/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Using IPython's Rich Display System
# -----------------------------------
#
# IPython has a [rich display system](bit.ly/HHPOac) for
# interactive widgets.

from IPython.display import IFrame
from IPython.core.display import display

# Define a google maps function.
def gmaps(query):
  url = "https://maps.google.com/maps?q={0}&output=embed".format(query)
  display(IFrame(url, '700px', '450px'))

gmaps("Golden Gate Bridge")
# Out:
#         <iframe
#             width="700px"
#             height="450px"
#             src="https://maps.google.com/maps?q=Golden Gate Bridge&output=embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import os 
import pyodbc
import pandas as pd

os.environ['ODBCINI']='/opt/cloudera/impalaodbc/Setup/odbc.ini'
os.environ['ODBCSYSINI']='/opt/cloudera/impalaodbc/Setup/'

impala_conn = pyodbc.connect(
	DSN="ImpalaDSN",
	driver="Cloudera_ODBC_Driver",
	autocommit = True)

# %%
with impala_conn : 
    data_df = pd.read_sql("SELECT * FROM default.cars93", impala_conn)

# %%
data_df.head()
# Out:
#    no manufacturer    model     type  min_price      price  max_price  \
# 0   1        Acura  Integra    Small  12.900000  15.900000  18.799999
# 1   2        Acura   Legend  Midsize  29.200001  33.900002  38.700001
# 2   3         Audi       90  Compact  25.900000  29.100000  32.299999
# 3   4         Audi      100  Midsize  30.799999  37.700001  44.599998
# 4   5          BMW     535i  Midsize  23.700001  30.000000  36.200001
#
#    mpg_city  mpg_highway             airbags  ... passengers length  \
# 0      25.0         31.0                None  ...        5.0  177.0
# 1      18.0         25.0  Driver & Passenger  ...        5.0  195.0
# 2      20.0         26.0         Driver only  ...        5.0  180.0
# 3      19.0         26.0  Driver & Passenger  ...        6.0  193.0
# 4      22.0         30.0         Driver only  ...        4.0  186.0
#
#    wheelbase  width  turn_circle  rear_seat_room luggage_room  weight  \
# 0      102.0   68.0         37.0            26.5         11.0    2705
# 1      115.0   71.0         38.0            30.0         15.0    3560
# 2      102.0   67.0         37.0            28.0         14.0    3375
# 3      106.0   70.0         37.0            31.0         17.0    3405
# 4      109.0   69.0         39.0            27.0         13.0    3640
#
#     origin           make
# 0  non-USA  Acura Integra
# 1  non-USA   Acura Legend
# 2  non-USA        Audi 90
# 3  non-USA       Audi 100
# 4  non-USA       BMW 535i
#
# [5 rows x 28 columns]
